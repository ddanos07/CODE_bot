# %% [markdown]
# <a href="https://colab.research.google.com/github/ddanos07/CODE_bot/blob/master/%EC%9E%89%EA%B8%B0%EB%AA%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O Dataset.zip https://universe.roboflow.com/ds/670VFcnfPs?key=rFI3Ay6gz0
# Out:
# --2023-07-08 16:44:51--  https://universe.roboflow.com/ds/670VFcnfPs?key=rFI3Ay6gz0
# Resolving universe.roboflow.com (universe.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to universe.roboflow.com (universe.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/SIcQKQidVFTxngVgPvT2G9mn8T52/XAONZEb4g5JYO7r8gR1W/1/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230708%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230708T164451Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
import zipfile

with zipfile.ZipFile("/content/Dataset.zip") as target_file:
  target_file.extractall('/content/Dataset')

# %%
# !pip install PyYAML

# %%
# !cat /content/Dataset/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['apple']
#
# roboflow:
#   workspace: lakshantha-dissanayake
#   project: apple-detection-5z37o
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/lakshantha-dissanayake/apple-detection-5z37o/dataset/1

# %%
import yaml

data = {
    'train':'/content/Dataset/train/images',
    'val':'/content/Dataset/valid/images',
    'test':'/content/Dataset/test/images',
    'nc': 1,
    'names': ['apple']
}
with open('/content/Dataset/data.yaml', 'w') as f:
  yaml.dump(data, f)

with open('/content/Dataset/data.yaml', 'r') as f:
  yaml = yaml.safe_load(f)
  display(yaml)

# print(data)
# Out:
# {'names': ['apple'],
#  'nc': 1,
#  'test': '/content/Dataset/test/images',
#  'train': '/content/Dataset/train/images',
#  'val': '/content/Dataset/valid/images'}

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.9/626.9 kB 26.6 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8m')

# %%
model.train(data='/content/Dataset/data.yaml', epochs=100, patience = 30, batch=32,imgsz=416)
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.predict(source="/content/3217_5050_1757.jpg",save=True )
# Out:
# image 1/1 /content/3217_5050_1757.jpg: 288x416 9 apples, 384.4ms
# Speed: 15.9ms preprocess, 384.4ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 416)
# Results saved to runs/detect/predict2
